# %%
from lib.utils import load_config
from lib.data.sketch import (
    render_shapenet,
    image_grid,
    image_to_sketch,
    obj_path,
    sketch_path,
    image_path,
    cartesian_elev_azim,
)

config = load_config()
obj1 = obj_path(config.obj_ids[0], config=config)
obj2 = obj_path(config.obj_ids[1], config=config)

elev, azim = cartesian_elev_azim(elev=config.elev, azim=config.azim)
images = render_shapenet(obj1, color=config.color, elev=elev, azim=azim)
image_grid(images, rows=5, cols=10)

# %%
sketches = image_to_sketch(images)
image_grid(sketches, rows=5, cols=10)
